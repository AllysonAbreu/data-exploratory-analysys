# %%
import pandas as pd

# %% [markdown]
# # Importando base de dados

# %%
pd.read_csv('dados/tips.csv')
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados = pd.read_csv('dados/tips.csv')

# %%
dados.head(10)
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4
# 5       25.29  4.71      No  Sun  Dinner     4
# 6        8.77  2.00      No  Sun  Dinner     2
# 7       26.88  3.12      No  Sun  Dinner     4
# 8       15.04  1.96      No  Sun  Dinner     2
# 9       14.78  3.23      No  Sun  Dinner     2

# %% [markdown]
# ## Tradução

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill' : 'valor_da_conta',
    'tip' : 'gorjeta',
    'dessert' : 'sobremesa',
    'day' : 'dia_da_semana',
    'time' : 'hora_do_dia',
    'size' : 'total_de_pessoas'
}

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No' : 'Não',
    'Yes' : 'Sim'
}

# %%
gorjetas.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
    'Sun' : 'Domingo',
    'Sat' : 'Sábado',
    'Thur' : 'Quinta',
    'Fri' : 'Sexta'
}

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dias)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner' : 'Jantar', 
    'Lunch' : 'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.tail() # exibe os últimos cinco itens do DataFrame
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não        Quinta      Jantar
#
#      total_de_pessoas
# 239                 3
# 240                 2
# 241                 2
# 242                 2
# 243                 2

# %%
# Deletar uma coluna do DataFrame = tips.drop('day', axis=1)

# %% [markdown]
# # Importando o seaborn

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.11.1
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: c:\users\allys\anaconda3\lib\site-packages
# Requires: numpy, matplotlib, scipy, pandas
# Required-by:

# %% [markdown]
# ## Análise 1 - Valor da conta e gorjeta

# %%
gorjetas.columns
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'total_de_pessoas'],
#       dtype='object')

# %%
valor_gorjeta = sns.scatterplot(x='valor_da_conta', y='gorjeta', data=gorjetas).figure.suptitle('Valor da conta X Gorjeta')
# valor_gorjeta.get_figure() visualizar somente a figura

# %% [markdown]
# **Visualmente, o valor da gorjeta aumenta conforme aumenta o valor da conta**

# %%
valor_gorjeta_linha = sns.relplot(x='valor_da_conta', y='gorjeta', kind = 'line', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', data=gorjetas)

# %%
print(f'A base de dados contém {gorjetas.shape[0]} registros.')
print('Registros não nulos')
gorjetas.count()
# Out:
# A base de dados contém 244 registros.
# Registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## Criando o campo porcentagem

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas['valor_da_conta']

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447

# %%
gorjetas.porcentagem = gorjetas.porcentagem.round(2)

# %%
gorjetas.head(5)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# **Visualmente, o valor da conta não é proporcional ao valor da gorjeta**

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem', kind = 'line', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# # Análise 02 - Sobremesas

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %%
sns.catplot(x='sobremesa', y='gorjeta', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa',data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa',col='sobremesa',data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', col='sobremesa',data = gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', kind = 'line',col='sobremesa',data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='sobremesa', kind = 'line',col='sobremesa',data = gorjetas)

# %% [markdown]
# **Visualmente, existe uma diferença no valor da gorjeta daqueles que pediram e não pediram sobremesas**

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta e a mesma nos dois grupos**
#
# **H<sup>alt</sup>**
# > **A distribuição da taxa da gorjeta não e a mesma nos dois grupos**

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query('sobremesa == "Sim"').porcentagem
sobremesa
# Out:
# 56     0.08
# 58     0.16
# 60     0.16
# 61     0.14
# 62     0.18
#        ...
# 234    0.19
# 236    0.08
# 237    0.04
# 240    0.07
# 241    0.09
# Name: porcentagem, Length: 93, dtype: float64

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem
sem_sobremesa
# Out:
# 0      0.06
# 1      0.16
# 2      0.17
# 3      0.14
# 4      0.15
#        ...
# 235    0.12
# 238    0.13
# 239    0.20
# 242    0.10
# 243    0.16
# Name: porcentagem, Length: 151, dtype: float64

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print(f'O valor do p-value é {r.pvalue}')
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta e a mesma nos dois grupos**
#
# > O p-value representa a probabilidade daquela amostra ter acontecido dentro da população. Se a chance é pequena, geralmente p-value < 0,05, representa que um evento muito raro aconteceu, então optamos por descartar a hipótese nula, e dizer que ela pode não ser verdade.

# %% [markdown]
# # Análise 03 - Dias da semana

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
gorjetas[gorjetas.dia_da_semana == 'Domingo'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       76.000000  76.000000         76.000000    76.000000
# mean        21.410000   3.255132          2.842105     0.166974
# std          8.832122   1.234880          1.007341     0.084759
# min          7.250000   1.010000          2.000000     0.060000
# 25%         14.987500   2.037500          2.000000     0.120000
# 50%         19.630000   3.150000          2.000000     0.160000
# 75%         25.597500   4.000000          4.000000     0.190000
# max         48.170000   6.500000          6.000000     0.710000

# %%
gorjetas[gorjetas.dia_da_semana == 'Sábado'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       87.000000  87.000000         87.000000    87.000000
# mean        20.441379   2.993103          2.517241     0.153678
# std          9.480419   1.631014          0.819275     0.051152
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.905000   2.000000          2.000000     0.120000
# 50%         18.240000   2.750000          2.000000     0.150000
# 75%         24.740000   3.370000          3.000000     0.190000
# max         50.810000  10.000000          5.000000     0.330000

# %%
gorjetas[gorjetas.dia_da_semana == 'Quinta'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       62.000000  62.000000         62.000000    62.000000
# mean        17.682742   2.771452          2.451613     0.161129
# std          7.886170   1.240223          1.066285     0.038713
# min          7.510000   1.250000          1.000000     0.070000
# 25%         12.442500   2.000000          2.000000     0.140000
# 50%         16.200000   2.305000          2.000000     0.150000
# 75%         20.155000   3.362500          2.000000     0.190000
# max         43.110000   6.700000          6.000000     0.270000

# %%
gorjetas[gorjetas.dia_da_semana == 'Sexta'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       19.000000  19.000000         19.000000    19.000000
# mean        17.151579   2.734737          2.105263     0.169474
# std          8.302660   1.019577          0.567131     0.047781
# min          5.750000   1.000000          1.000000     0.100000
# 25%         12.095000   1.960000          2.000000     0.130000
# 50%         15.380000   3.000000          2.000000     0.160000
# 75%         21.750000   3.365000          2.000000     0.200000
# max         40.170000   4.730000          4.000000     0.260000

# %%
sns.catplot(x='dia_da_semana',y='valor_da_conta',data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', col='dia_da_semana',data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana',data = gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana',data = gorjetas)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean()

# %%
print(f'A média geral das gorjetas é de {media_geral_gorjetas}')
# Out:
# A média geral das gorjetas é de 2.9982786885245902

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta','gorjeta','porcentagem']]
# Out:
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
print('Frequência dos dias:')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias:
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição do valor da conta é igual no sábado e no domingo**
#
# **H<sup>alt</sup>**
# > **A distribuição do valor da conta não é igual no sábado e no domingo**

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta

# %%
r = ranksums(valor_conta_domingo, valor_conta_sabado)

# %%
print(f'O valor do p-value é {r.pvalue}')
# Out:
# O valor do p-value é 0.3576728477868443

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição do valor da conta é igual no sábado e no domingo.**
#
# > O p-value representa a probabilidade daquela amostra ter acontecido dentro da população. Se a chance é pequena, geralmente p-value < 0,05, representa que um evento muito raro aconteceu, então optamos por descartar a hipótese nula, e dizer que ela pode não ser verdade.

# %% [markdown]
# # Análise 4 - Hora do dia

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data = gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta',kind='swarm', data = gorjetas)

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data = gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
gorjetas[gorjetas.hora_do_dia == 'Jantar'].describe()[['valor_da_conta','gorjeta','porcentagem']]
# Out:
#        valor_da_conta     gorjeta  porcentagem
# count      176.000000  176.000000   176.000000
# mean        20.797159    3.102670     0.159773
# std          9.142029    1.436243     0.067426
# min          3.070000    1.000000     0.040000
# 25%         14.437500    2.000000     0.120000
# 50%         18.390000    3.000000     0.160000
# 75%         25.282500    3.687500     0.190000
# max         50.810000   10.000000     0.710000

# %%
gorjetas[gorjetas.hora_do_dia == 'Almoço'].describe()[['valor_da_conta','gorjeta','porcentagem']]
# Out:
#        valor_da_conta    gorjeta  porcentagem
# count       68.000000  68.000000    68.000000
# mean        17.168676   2.728088     0.163971
# std          7.713882   1.205345     0.040266
# min          7.510000   1.250000     0.070000
# 25%         12.235000   2.000000     0.140000
# 50%         15.965000   2.250000     0.150000
# 75%         19.532500   3.287500     0.190000
# max         43.110000   6.700000     0.270000

# %%
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data = gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
sns.displot(almoco, kde=True)

# %%
jantar = gorjetas.query("hora_do_dia == 'Jantar'").valor_da_conta

# %%
sns.displot(jantar, kde=True)

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta','porcentagem']]
# Out:
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.163971
# Jantar            20.797159  3.102670     0.159773

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição do valor da conta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
# > **A distribuição do valor da conta não é igual no jantar e no almoço**

# %%
r = ranksums(jantar,almoco)

# %%
print(f'O valor do p-value é de {r.pvalue}')
# Out:
# O valor do p-value é de 0.0011791039723641672

# %% [markdown]
# **H<sup>alt</sup>**
# > **A distribuição do valor da conta não é igual no jantar e no almoço**

# %% [markdown]
# ## Teste de hipótese 2

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
# > **A distribuição da taxa da gorjeta não é igual no jantar e no almoço**

# %%
porcentagem_almoco = gorjetas.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjetas.query("hora_do_dia == 'Jantar'").porcentagem

# %%
r = ranksums(porcentagem_almoco, porcentagem_jantar)

# %%
print(f'O valor o p-value é de {r.pvalue}')
# Out:
# O valor o p-value é de 0.2602493995587126

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta é igual no jantar e no almoço**
