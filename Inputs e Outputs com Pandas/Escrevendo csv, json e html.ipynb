# %%
import pandas as pd

# %% [markdown]
# # Criando alunos para a Escola

# %% [markdown]
# ## Exportando lista JSON

# %%
nomes_m = pd.read_json('https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=m')
nomes_f = pd.read_json('https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=f')

# %%
print("Quantidade de nomes: " +str(len(nomes_f)+(len(nomes_m))))
# Out:
# Quantidade de nomes: 400

# %%
nomes_m
# Out:
#           nome  regiao     freq  rank sexo
# 0         JOSE       0  5732508     1    M
# 1         JOAO       0  2971935     2    M
# 2      ANTONIO       0  2567494     3    M
# 3    FRANCISCO       0  1765197     4    M
# 4       CARLOS       0  1483121     5    M
# ..         ...     ...      ...   ...  ...
# 195     WALTER       0    67207   196    M
# 196    ARLINDO       0    66669   197    M
# 197    MICHAEL       0    65736   198    M
# 198     ALVARO       0    65444   199    M
# 199    GEOVANE       0    65435   200    M
#
# [200 rows x 5 columns]

# %%
nomes_f
# Out:
#           nome  regiao      freq  rank sexo
# 0        MARIA       0  11694738     1    F
# 1          ANA       0   3079729     2    F
# 2    FRANCISCA       0    721637     3    F
# 3      ANTONIA       0    588783     4    F
# 4      ADRIANA       0    565621     5    F
# ..         ...     ...       ...   ...  ...
# 195     ROSANE       0     82203   196    F
# 196    IVONETE       0     81878   197    F
# 197    LUCIANE       0     81230   198    F
# 198    ISADORA       0     81100   199    F
# 199      NILZA       0     80128   200    F
#
# [200 rows x 5 columns]

# %%
frames = [nomes_f, nomes_m]

# %%
frames
# Out:
# [          nome  regiao      freq  rank sexo
#  0        MARIA       0  11694738     1    F
#  1          ANA       0   3079729     2    F
#  2    FRANCISCA       0    721637     3    F
#  3      ANTONIA       0    588783     4    F
#  4      ADRIANA       0    565621     5    F
#  ..         ...     ...       ...   ...  ...
#  195     ROSANE       0     82203   196    F
#  196    IVONETE       0     81878   197    F
#  197    LUCIANE       0     81230   198    F
#  198    ISADORA       0     81100   199    F
#  199      NILZA       0     80128   200    F
#
#  [200 rows x 5 columns],
#            nome  regiao     freq  rank sexo
#  0         JOSE       0  5732508     1    M
#  1         JOAO       0  2971935     2    M
#  2      ANTONIO       0  2567494     3    M
#  3    FRANCISCO       0  1765197     4    M
#  4       CARLOS       0  1483121     5    M
#  ..         ...     ...      ...   ...  ...
#  195     WALTER       0    67207   196    M
#  196    ARLINDO       0    66669   197    M
#  197    MICHAEL       0    65736   198    M
#  198     ALVARO       0    65444   199    M
#  199    GEOVANE       0    65435   200    M
#
#  [200 rows x 5 columns]]

# %%
nomes = pd.concat(frames)['nome'].to_frame()

# %%
nomes.sample(5)
# Out:
#            nome
# 169  WELLINGTON
# 142      RAISSA
# 31      RICARDO
# 73      JANAINA
# 36       DEBORA

# %%
nomes
# Out:
#           nome
# 0        MARIA
# 1          ANA
# 2    FRANCISCA
# 3      ANTONIA
# 4      ADRIANA
# ..         ...
# 195     WALTER
# 196    ARLINDO
# 197    MICHAEL
# 198     ALVARO
# 199    GEOVANE
#
# [400 rows x 1 columns]

# %%
nomes.shape
# Out:
# (400, 1)

# %%
nomes.index = range(nomes.shape[0])

# %%
nomes
# Out:
#           nome
# 0        MARIA
# 1          ANA
# 2    FRANCISCA
# 3      ANTONIA
# 4      ADRIANA
# ..         ...
# 395     WALTER
# 396    ARLINDO
# 397    MICHAEL
# 398     ALVARO
# 399    GEOVANE
#
# [400 rows x 1 columns]

# %% [markdown]
# ## Incluindo ID dos Alunos

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 400

# %%
nomes['id_alunos'] = np.random.permutation(total_alunos) + 1

# %%
nomes.sample(5)
# Out:
#           nome  id_alunos
# 188    POLIANA        369
# 57      DAIANE        303
# 203  FRANCISCO        382
# 382    CHARLES         33
# 230   ANDERSON        111

# %%
dominios = ['@dominiodoemail.com.br','@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios,total_alunos)

# %%
nomes.sample(5)
# Out:
#           nome  id_alunos                 dominio
# 284   SEVERINO         78  @dominiodoemail.com.br
# 200       JOSE        331     @servicodoemail.com
# 379       IAGO        340  @dominiodoemail.com.br
# 10      SANDRA        174  @dominiodoemail.com.br
# 171  TERESINHA         45  @dominiodoemail.com.br

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes.sample(5)
# Out:
#        nome  id_alunos                 dominio                         email
# 314  ARTHUR        320  @dominiodoemail.com.br  arthur@dominiodoemail.com.br
# 57   DAIANE        303     @servicodoemail.com     daiane@servicodoemail.com
# 85   HELENA        221  @dominiodoemail.com.br  helena@dominiodoemail.com.br
# 183   IRACI          8  @dominiodoemail.com.br   iraci@dominiodoemail.com.br
# 189   DALVA        137  @dominiodoemail.com.br   dalva@dominiodoemail.com.br

# %% [markdown]
# # Criando a tabela cursos

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %% [markdown]
# ## Alterando o index dos cursos

# %%
cursos = cursos.rename(columns = {'Nome do curso':'nome_do_curso'})

# %%
cursos.head(2)
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web

# %%
cursos['id'] = cursos.index + 1

# %%
cursos
# Out:
#                           nome_do_curso  id
# 0                 Lógica de programação   1
# 1                         Java para Web   2
# 2                           C# para Web   3
# 3                         Ruby on Rails   4
# 4                      Cursos de Python   5
# 5                         PHP com MySql   6
# 6                         .NET para web   7
# 7            Novas integrações com Java   8
# 8                          TDD com Java   9
# 9                   Código limpo com C#  10
# 10  Preparatório para certificação Java  11
# 11                      Hardware básico  12
# 12                Persistência com .NET  13
# 13                  Desenvolvendo jogos  14
# 14                     Análise de dados  15
# 15                   Estatística básica  16
# 16                  Internet das coisas  17
# 17                Programação funcional  18
# 18                Boas práticas em Java  19
# 19          Orientação objetos com Java  20

# %%
cursos = cursos.set_index('id')

# %%
cursos
# Out:
#                           nome_do_curso
# id
# 1                 Lógica de programação
# 2                         Java para Web
# 3                           C# para Web
# 4                         Ruby on Rails
# 5                      Cursos de Python
# 6                         PHP com MySql
# 7                         .NET para web
# 8            Novas integrações com Java
# 9                          TDD com Java
# 10                  Código limpo com C#
# 11  Preparatório para certificação Java
# 12                      Hardware básico
# 13                Persistência com .NET
# 14                  Desenvolvendo jogos
# 15                     Análise de dados
# 16                   Estatística básica
# 17                  Internet das coisas
# 18                Programação funcional
# 19                Boas práticas em Java
# 20          Orientação objetos com Java

# %% [markdown]
# # Matriculando os alunos nos cursos

# %%
nomes.sample(5)
# Out:
#          nome  id_alunos                 dominio  \
# 59     ISABEL         83  @dominiodoemail.com.br
# 172    REBECA        165     @servicodoemail.com
# 330    JUNIOR        184  @dominiodoemail.com.br
# 270   JOAQUIM        248     @servicodoemail.com
# 371  VALDEMIR          3  @dominiodoemail.com.br
#
#                               email
# 59     isabel@dominiodoemail.com.br
# 172       rebeca@servicodoemail.com
# 330    junior@dominiodoemail.com.br
# 270      joaquim@servicodoemail.com
# 371  valdemir@dominiodoemail.com.br

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos) * 1.5).astype(int)

# %%
nomes.sample(5)
# Out:
#         nome  id_alunos                 dominio  \
# 294     JAIR        344  @dominiodoemail.com.br
# 397  MICHAEL        323  @dominiodoemail.com.br
# 334  ALBERTO        245  @dominiodoemail.com.br
# 288   GILMAR        142     @servicodoemail.com
# 189    DALVA        137  @dominiodoemail.com.br
#
#                              email  matriculas
# 294     jair@dominiodoemail.com.br           2
# 397  michael@dominiodoemail.com.br           1
# 334  alberto@dominiodoemail.com.br           3
# 288      gilmar@servicodoemail.com           2
# 189    dalva@dominiodoemail.com.br           1

# %%
nomes.matriculas.describe()
# Out:
# count    400.000000
# mean       2.100000
# std        1.464706
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        8.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)
# Out:
# C:\Users\allys\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='matriculas', ylabel='Density'>

# %%
nomes.matriculas.value_counts()
# Out:
# 1    186
# 2    103
# 3     56
# 4     27
# 6     10
# 5      9
# 7      5
# 8      4
# Name: matriculas, dtype: int64

# %% [markdown]
# ## Selecionando cursos

# %%
nomes.sample(5)
# Out:
#           nome  id_alunos                 dominio  \
# 267   HENRIQUE         64  @dominiodoemail.com.br
# 17     LUCIANA        163  @dominiodoemail.com.br
# 377  CLAUDINEI        254     @servicodoemail.com
# 398     ALVARO        383  @dominiodoemail.com.br
# 374      DENIS         69     @servicodoemail.com
#
#                               email  matriculas
# 267  henrique@dominiodoemail.com.br           7
# 17    luciana@dominiodoemail.com.br           1
# 377    claudinei@servicodoemail.com           3
# 398    alvaro@dominiodoemail.com.br           2
# 374        denis@servicodoemail.com           1

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index,row in nomes.iterrows():
    id = row.id_alunos
    matriculas = row.matriculas
    for i in range(matriculas):
        mat = [id, np.random.choice(cursos.index, p = prob)]
        todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas, columns = ['id_aluno','id_curso'])

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0       235         7
# 1        43        14
# 2        43         2
# 3       304         5
# 4       304         1

# %%
matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                           30                Lógica de programação
# 2                           62                        Java para Web
# 3                           24                          C# para Web
# 4                            7                        Ruby on Rails
# 5                           77                     Cursos de Python
# 6                           21                        PHP com MySql
# 7                           33                        .NET para web
# 8                           43           Novas integrações com Java
# 9                           26                         TDD com Java
# 10                          20                  Código limpo com C#
# 11                          28  Preparatório para certificação Java
# 12                          49                      Hardware básico
# 13                          17                Persistência com .NET
# 14                          62                  Desenvolvendo jogos
# 15                          83                     Análise de dados
# 16                          24                   Estatística básica
# 17                          36                  Internet das coisas
# 18                          71                Programação funcional
# 19                          70                Boas práticas em Java
# 20                          57          Orientação objetos com Java

# %%
nomes.sample(3)
# Out:
#          nome  id_alunos                 dominio  \
# 285  FABRICIO         59  @dominiodoemail.com.br
# 12     AMANDA        217     @servicodoemail.com
# 110   LUCIENE         22  @dominiodoemail.com.br
#
#                               email  matriculas
# 285  fabricio@dominiodoemail.com.br           6
# 12        amanda@servicodoemail.com           1
# 110   luciene@dominiodoemail.com.br           1

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0       235         7
# 1        43        14
# 2        43         2
# 3       304         5
# 4       304         1

# %%
 matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})

# %%
matriculas_por_curso
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                           30                Lógica de programação
# 2                           62                        Java para Web
# 3                           24                          C# para Web
# 4                            7                        Ruby on Rails
# 5                           77                     Cursos de Python
# 6                           21                        PHP com MySql
# 7                           33                        .NET para web
# 8                           43           Novas integrações com Java
# 9                           26                         TDD com Java
# 10                          20                  Código limpo com C#
# 11                          28  Preparatório para certificação Java
# 12                          49                      Hardware básico
# 13                          17                Persistência com .NET
# 14                          62                  Desenvolvendo jogos
# 15                          83                     Análise de dados
# 16                          24                   Estatística básica
# 17                          36                  Internet das coisas
# 18                          71                Programação funcional
# 19                          70                Boas práticas em Java
# 20                          57          Orientação objetos com Java

# %% [markdown]
# ## Saída em diferentes formatos

# %%
matriculas_por_curso.head(3)
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                           30  Lógica de programação
# 2                           62          Java para Web
# 3                           24            C# para Web

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index=False)

# %%
matriculas_por_curso.to_json('matriculas_por_curso.json')

# %%
matriculas_json = matriculas_por_curso.to_json()

# %%
matriculas_json
# Out:
# '{"quantidade_de_alunos":{"1":30,"2":62,"3":24,"4":7,"5":77,"6":21,"7":33,"8":43,"9":26,"10":20,"11":28,"12":49,"13":17,"14":62,"15":83,"16":24,"17":36,"18":71,"19":70,"20":57},"nome_do_curso":{"1":"L\\u00f3gica de programa\\u00e7\\u00e3o","2":"Java para Web","3":"C# para Web","4":"Ruby on Rails","5":"Cursos de Python","6":"PHP com MySql","7":".NET para web","8":"Novas integra\\u00e7\\u00f5es com Java","9":"TDD com Java","10":"C\\u00f3digo limpo com C#","11":"Preparat\\u00f3rio para certifica\\u00e7\\u00e3o Java","12":"Hardware b\\u00e1sico","13":"Persist\\u00eancia com .NET","14":"Desenvolvendo jogos","15":"An\\u00e1lise de dados","16":"Estat\\u00edstica b\\u00e1sica","17":"Internet das coisas","18":"Programa\\u00e7\\u00e3o funcional","19":"Boas pr\\u00e1ticas em Java","20":"Orienta\\u00e7\\u00e3o objetos com Java"}}'

# %%
matriculas_html = matriculas_por_curso.to_html()

# %%
print(matriculas_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantidade_de_alunos</th>
#       <th>nome_do_curso</th>
#     </tr>
#     <tr>
#       <th>id_curso</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>30</td>
#       <td>Lógica de programação</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>62</td>
#       <td>Java para Web</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>24</td>
#       <td>C# para Web</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7</td>
#       <td>Ruby on Rails</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>77</td>
#       <td>Cursos de Python</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>21</td>
#       <td>PHP com MySql</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>33</td>
#       <td>.NET para web</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>43</td>
#       <td>Novas integrações com Java</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>26</td>
#       <td>TDD com Java</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>20</td>
#       <td>Código limpo com C#</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>28</td>
#       <td>Preparatório para certificação Java</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>49</td>
#       <td>Hardware básico</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>17</td>
#       <td>Persistência com .NET</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>62</td>
#       <td>Desenvolvendo jogos</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>83</td>
#       <td>Análise de dados</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>24</td>
#       <td>Estatística básica</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>36</td>
#       <td>Internet das coisas</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>71</td>
#       <td>Programação funcional</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>70</td>
#       <td>Boas práticas em Java</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>57</td>
#       <td>Orientação objetos com Java</td>
#     </tr>
#   </tbody>
# </table>

# %%
matriculas_por_curso.to_html('matriculas_por_curso.html')
